# %%
# !pip install numpy pytest
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pytest tests/test_board.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 24 items
#
# tests/test_board.py::TestInit::test_shape PASSED                         [  4%]
# tests/test_board.py::TestInit::test_dtype PASSED                         [  8%]
# tests/test_board.py::TestInit::test_all_cells_empty PASSED               [ 12%]
# tests/test_board.py::TestPlaceSymbol::test_returns_true_on_success PASSED [ 16%]
# tests/test_board.py::TestPlaceSymbol::test_symbol_written_to_grid PASSED [ 20%]
# tests/test_board.py::TestPlaceSymbol::test_returns_false_when_occupied PASSED [ 25%]
# tests/test_board.py::TestPlaceSymbol::test_occupied_cell_unchanged PASSED [ 29%]
# tests/test_board.py::TestPlaceSymbol::test_all_corners_placeable PASSED  [ 33%]
# ...

# %%
# !pytest tests/test_referee.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 20 items
#
# tests/test_referee.py::TestCheckWinnerX::test_top_row PASSED             [  5%]
# tests/test_referee.py::TestCheckWinnerX::test_middle_row PASSED          [ 10%]
# tests/test_referee.py::TestCheckWinnerX::test_bottom_row PASSED          [ 15%]
# tests/test_referee.py::TestCheckWinnerX::test_left_col PASSED            [ 20%]
# tests/test_referee.py::TestCheckWinnerX::test_middle_col PASSED          [ 25%]
# tests/test_referee.py::TestCheckWinnerX::test_right_col PASSED           [ 30%]
# tests/test_referee.py::TestCheckWinnerX::test_main_diagonal PASSED       [ 35%]
# tests/test_referee.py::TestCheckWinnerX::test_anti_diagonal PASSED       [ 40%]
# ...

# %%
# !pytest tests/test_player.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 17 items
#
# tests/test_player.py::TestInit::test_player_id_stored PASSED             [  5%]
# tests/test_player.py::TestInit::test_default_is_human PASSED             [ 11%]
# tests/test_player.py::TestInit::test_is_computer_flag PASSED             [ 17%]
# tests/test_player.py::TestInit::test_symbol_none_on_creation PASSED      [ 23%]
# tests/test_player.py::TestInit::test_has_symbol_false_on_creation PASSED [ 29%]
# tests/test_player.py::TestSetSymbol::test_set_x PASSED                   [ 35%]
# tests/test_player.py::TestSetSymbol::test_set_o PASSED                   [ 41%]
# tests/test_player.py::TestSetSymbol::test_has_symbol_true_after_set PASSED [ 47%]
# ...

# %%
# !pytest tests/test_game.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 24 items
#
# tests/test_game.py::TestStartNewGame::test_board_cleared_on_start PASSED [  4%]
# tests/test_game.py::TestStartNewGame::test_game_over_reset_on_start PASSED [  8%]
# tests/test_game.py::TestStartNewGame::test_first_player_is_random PASSED [ 12%]
# tests/test_game.py::TestStartNewGame::test_can_force_p1_first PASSED     [ 16%]
# tests/test_game.py::TestStartNewGame::test_can_force_p2_first PASSED     [ 20%]
# tests/test_game.py::TestSwitchTurns::test_switches_from_p1_to_p2 PASSED  [ 25%]
# tests/test_game.py::TestSwitchTurns::test_switches_from_p2_to_p1 PASSED  [ 29%]
# ...

# %%
# !pytest tests/test_json_manager.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 37 items
#
# tests/test_json_manager.py::TestInit::test_file_created_on_init PASSED   [  2%]
# tests/test_json_manager.py::TestInit::test_new_file_contains_empty_dict PASSED [  5%]
# tests/test_json_manager.py::TestInit::test_existing_file_not_overwritten PASSED [  8%]
# tests/test_json_manager.py::TestLoadSave::test_save_then_load_roundtrip PASSED [ 10%]
# tests/test_json_manager.py::TestLoadSave::test_save_overwrites_previous PASSED [ 13%]
# tests/test_json_manager.py::TestLoadSave::test_load_returns_dict PASSED  [ 16%]
# tests/test_json_manager.py::TestCreatePlayer::test_player_added PASSED   [ 18%]
# ...

# %%
# !pytest tests/test_leaderboard.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 35 items
#
# tests/test_leaderboard.py::TestGetTotalWins::test_alex_wins PASSED       [  2%]
# tests/test_leaderboard.py::TestGetTotalWins::test_nash_wins PASSED       [  5%]
# tests/test_leaderboard.py::TestGetTotalWins::test_zero_wins PASSED       [  8%]
# tests/test_leaderboard.py::TestGetTotalWins::test_unknown_player_raises PASSED [ 11%]
# tests/test_leaderboard.py::TestGetTotalLosses::test_alex_losses PASSED   [ 14%]
# tests/test_leaderboard.py::TestGetTotalLosses::test_nash_losses PASSED   [ 17%]
# tests/test_leaderboard.py::TestGetTotalLosses::test_zero_losses PASSED   [ 20%]
# ...

# %%
# !pytest tests/test_minimax_ai.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\ProgramData\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Sylva Mindi-Ebite\Desktop\BenPython\tictactoe
# plugins: anyio-4.10.0
# collecting ... collected 17 items
#
# tests/test_minimax_ai.py::TestContract::test_returns_tuple PASSED        [  5%]
# tests/test_minimax_ai.py::TestContract::test_returns_two_ints PASSED     [ 11%]
# tests/test_minimax_ai.py::TestContract::test_move_is_within_bounds PASSED [ 17%]
# tests/test_minimax_ai.py::TestContract::test_move_targets_empty_cell PASSED [ 23%]
# tests/test_minimax_ai.py::TestContract::test_full_board_raises PASSED    [ 29%]
# tests/test_minimax_ai.py::TestContract::test_board_unchanged_after_call PASSED [ 35%]
# tests/test_minimax_ai.py::TestTakeWin::test_win_via_row PASSED           [ 41%]
# ...

# %%
# %run console_game.py
# Out:
# ...
#               TIC-TAC-TOE
# ...
#
#   [1]  Player vs Player
#   [2]  Player vs Computer
#   [3]  Leaderboard
#   [4]  Exit
#   Choose:  3
# ...
#               LEADERBOARD
# ...
#
#   #    Player                  W    L    D    Rate
#   ────────────────────────────────────────────
#   1    Nash's heir             2    0    4   33.3%
#   2    Mindi                   1    2    5   12.5%
#   3    Ebuka                   0    1    1    0.0%
#   4    Laa                     0    0    0    0.0%
#   Press Enter to return to main menu…
# ...
#               TIC-TAC-TOE
# ...
#
#   [1]  Player vs Player
#   [2]  Player vs Computer
#   [3]  Leaderboard
#   [4]  Exit
#   Choose:  4
#   Thank you for playing. Goodbye!

# %%
import sys
# !{sys.executable} -m pip install customtkinter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/2 [darkdetect]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    -------------------- ------------------- 1/2 [customtkinter]
#    ---------------------------------------- 2/2 [customtkinter]
#
# ...

# %%
import customtkinter as ctk
print(ctk.__version__)
# Out:
# 5.2.2

# %%
# %run tests/test_main_menu_frame.py
# Out:
# Click each button and check the [NAV] output below.
# Close the window when done.

# %%
# %run tests/test_exit_frame.py
# Out:
# Window will auto-close in 2 seconds...
# Window closed. Visual test passed.

# %%
# %run tests/test_select_id_frame.py
# Out:
# .............................
# ----------------------------------------------------------------------
# Ran 29 tests in 2.459s
#
# OK

# %%
# %run tests/test_select_symbol_frame.py
# Out:
# ................
# ----------------------------------------------------------------------
# Ran 16 tests in 0.788s
#
# OK

# %%
# %run tests/test_game_background_frame.py
# Out:
# .........................
# ----------------------------------------------------------------------
# Ran 25 tests in 0.610s
#
# OK

# %%
# %run tests/test_grid_toplevel_frame.py
# Out:
# ...........................
# ----------------------------------------------------------------------
# Ran 27 tests in 0.961s
#
# OK

# %%
# %run tests/test_result_modal.py
# Out:
# ........................
# ----------------------------------------------------------------------
# Ran 24 tests in 0.904s
#
# OK

# %%
# %run tests/test_leaderboard_frame.py
# Out:
# ........................
# ----------------------------------------------------------------------
# Ran 24 tests in 1.020s
#
# OK

# %%
# %run tests/test_app.py
# Out:
# ................................
# ----------------------------------------------------------------------
# Ran 32 tests in 4.027s
#
# OK

# %%
# %run main.py
